# %% [markdown]
# # Un progetto dall'inizio alla fine: lavoriamo con dati reali
#
# Siete stati assunti come Data Specialist da una azienda che svolge analisi statistiche del mercato immobiliare americano. Ecco gli step che realizzeremo in questo progetto: Il vostro compito e' predirre il prezzo di una casa in california dato il numero di stanze e la posizione e altre carateristiche. <br>
#
# La checklist semplificata del progetto sara':
#
# - [] Guardiamo al quadro generale (Big Picture)
# - [] Procuriamoci i dati
# - [] Analizziamo e visualizziamo i dati per acquisirne consapevolezza
# - [] Prepara i dati per l'algoritmo di Machine Learning
# - [] Seleziona il modello e addesteralo
# - [] Ottimizza il modello con una messa a punto
# - [] Presenta la soluzione
# - [] Lancia, Monitora e Mantieni il tuo modello

# %% [markdown]
# ## 1 - The Big Picture, inquadriamo il problema
# ### 1.1 - La fonte dei dati:
# - Repository popolari:
#     - [Irvine](https://archive.ics.uci.edu)
#     - [Kaggle](https://www.kaggle.com)
#     - [Amazone AWS](https://registry.opendata.aws)
# - Meta Portali:
#     - [Data Portals](https://dataportals.org)
#     - [Open Data Watch](https://opendatawatch.com/monitoring/)
#     - [Quandl](https://data.nasdaq.com/publishers/QDL)
# - Raccolte di link a repo:
#     - [Quora](https://www.quora.com/Where-can-I-find-large-datasets-open-to-the-public)
#     - [Wikipedia](https://en.wikipedia.org/wiki/List_of_datasets_for_machine-learning_research)
#     - [Reddit](https://www.reddit.com/r/datasets/)
#
# ### 1.2 - Procuriamoci i dati:
# Per il download dei dati da web e' sempre conveniente scrivere una funzione che possa essere richiamata in automatcoa seconda delle esigenze.

# %%
# Download dei dati
from pathlib import Path
import pandas as pd
import tarfile
import urllib.request
import matplotlib.pyplot as plt

def load_housing_data():
    """
    Carica il dataset degli alloggi.

    Output:
    DataFrame: Un DataFrame di pandas contenente i dati degli alloggi.

    Descrizione:
    Questa funzione verifica se il file 'housing.tgz' esiste nel percorso specificato. 
    Se il file non esiste, lo scarica da un URL fornito, lo estrae e legge il file CSV 
    'housing.csv' da una directory specificata, restituendo infine i dati in un DataFrame di pandas.
    """

    # Percorso del file tarball
    tarball_path = Path("datasets/housing.tgz")

    # Se il file non esiste, scarica ed estrai i dati
    if not tarball_path.is_file():
        # Crea la directory se non esiste
        Path("datasets").mkdir(parents=True, exist_ok=True)
        
        # URL da cui scaricare i dati
        url = "https://github.com/ageron/data/raw/main/housing.tgz"

        # Scarica il file tarball
        urllib.request.urlretrieve(url, tarball_path)

        # Estrae il file tarball
        with tarfile.open(tarball_path) as housing_tarball:
            housing_tarball.extractall(path="datasets")
    
    # Legge il file CSV e lo restituisce come un DataFrame
    return pd.read_csv(Path("datasets/housing/housing.csv"))

housing = load_housing_data()
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# ### Analisi e valutazione dei dati
# Significato di ciscuna colonna
# -   **longitude:** longitudine della posizione dell'alloggio
# -   **latitude:** latitudine della posizione dell'alloggio
# -   **housing_median_age:** età media degli alloggi nella zona
# -   **total_rooms:** numero totale di stanze nell'alloggio
# -   **total_bedrooms:** numero totale di camere da letto nell'alloggio
# -   **population:** popolazione totale nella zona
# -   **households:** numero totale di famiglie nella zona
# -   **median_income:** reddito medio delle famiglie nella zona
# -   **median_house_value:** valore medio delle case nella zona
# -   **ocean_proximity:** prossimità all'oceano

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
print(f"Il dataset ha {housing.shape[0]} istanze e {housing.shape[1]} attributi")
# Out:
# Il dataset ha 20640 istanze e 10 attributi

# %%
#housing['ocean_proximity']
housing.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
#'total_bedrooms' contiene valori di tipo "None". Questo attributo andrà gestito.

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
housing.hist(bins=50, figsize=(10, 10));

# %%
#Attenzione alle grandezze "capped"
# Meglio normalizzare i dati
# Le campane simmetriche funzionano meglio

# %% [markdown]
# ### Creazione di un TestSet
# Prima guardare oltre nei dati e' molto importante separare una certa qauntita' di dati e metterla da parte senza toccarla. <br>
# Sarebbe importante che il test set sia mediamente rappresentativo di ciascun attributo. Se il dataset non e' molto grande potrebbe essere necessario crare un test set stratifiato.

# %%
from sklearn.model_selection import train_test_split

house_train, house_test = train_test_split(housing, test_size=0.2, random_state=42)

print(f"Train set: {house_train.shape}")
print(f"Test set: {house_test.shape}")

house_train.head()

housing = house_train.copy()

# Da questo momento housing contiene l'80% del dataset iniziale
# Out:
# Train set: (16512, 10)
# Test set: (4128, 10)

# %%
housing.shape
# Out:
# (16512, 10)

# %% [markdown]
# ### Exploring Data

# %%
housing.plot.scatter(x='longitude',
                     y='latitude',
                     alpha=0.4,
                     s=housing['population']/100,
                     c=housing['median_house_value'],
                     colormap='jet');

# %% [markdown]
# ### Correlations

# %%
correlation_housing = housing.drop(columns="ocean_proximity")

# %%
correlation_housing.corr().style.background_gradient(cmap='PiYG')
# Out:
# <style type="text/css">
# #T_b263c_row0_col0, #T_b263c_row1_col1, #T_b263c_row2_col2, #T_b263c_row3_col3, #T_b263c_row4_col4, #T_b263c_row5_col5, #T_b263c_row6_col6, #T_b263c_row7_col7, #T_b263c_row8_col8 {
#   background-color: #276419;
#   color: #f1f1f1;
# }
# #T_b263c_row0_col1, #T_b263c_row1_col0, #T_b263c_row1_col8, #T_b263c_row2_col3, #T_b263c_row2_col4, #T_b263c_row2_col5, #T_b263c_row2_col6, #T_b263c_row2_col7, #T_b263c_row3_col2 {
#   background-color: #8e0152;
#   color: #f1f1f1;
# }
# #T_b263c_row0_col2, #T_b263c_row6_col8 {
#   background-color: #da69a6;
#   color: #f1f1f1;
# }
# #T_b263c_row0_col3 {
#   background-color: #f1b5d9;
#   color: #000000;
# }
# #T_b263c_row0_col4 {
#   background-color: #f0b2d7;
#   color: #000000;
# }
# #T_b263c_row0_col5 {
#   background-color: #f1b7da;
#   color: #000000;
# }
# #T_b263c_row0_col6, #T_b263c_row1_col2 {
#   background-color: #eca6cf;
#   color: #000000;
# }
# #T_b263c_row0_col7 {
#   background-color: #c01879;
#   color: #f1f1f1;
# }
# #T_b263c_row0_col8 {
#   background-color: #bd1777;
#   color: #f1f1f1;
# }
# #T_b263c_row1_col3, #T_b263c_row7_col6 {
#   background-color: #e590bf;
#   color: #f1f1f1;
# }
# #T_b263c_row1_col4 {
#   background-color: #db6ca8;
#   color: #f1f1f1;
# }
# #T_b263c_row1_col5 {
#   background-color: #ce3d8f;
#   color: #f1f1f1;
# }
# #T_b263c_row1_col6 {
#   background-color: #d75ea1;
#   color: #f1f1f1;
# }
# #T_b263c_row1_col7, #T_b263c_row4_col2 {
#   background-color: #9f095f;
#   color: #f1f1f1;
# }
# #T_b263c_row2_col0, #T_b263c_row5_col1 {
#   background-color: #fce5f1;
#   color: #000000;
# }
# #T_b263c_row2_col1 {
#   background-color: #f8f4f6;
#   color: #000000;
# }
# #T_b263c_row2_col8 {
#   background-color: #e283b7;
#   color: #f1f1f1;
# }
# #T_b263c_row3_col0 {
#   background-color: #f7f7f6;
#   color: #000000;
# }
# #T_b263c_row3_col1, #T_b263c_row8_col0 {
#   background-color: #f9eef4;
#   color: #000000;
# }
# #T_b263c_row3_col4, #T_b263c_row4_col3 {
#   background-color: #3a7b1d;
#   color: #f1f1f1;
# }
# #T_b263c_row3_col5 {
#   background-color: #549825;
#   color: #f1f1f1;
# }
# #T_b263c_row3_col6 {
#   background-color: #3f811e;
#   color: #f1f1f1;
# }
# #T_b263c_row3_col7, #T_b263c_row8_col6 {
#   background-color: #eeabd2;
#   color: #000000;
# }
# #T_b263c_row3_col8 {
#   background-color: #e692c1;
#   color: #000000;
# }
# #T_b263c_row4_col0 {
#   background-color: #f4f7f0;
#   color: #000000;
# }
# #T_b263c_row4_col1, #T_b263c_row6_col1 {
#   background-color: #faeaf2;
#   color: #000000;
# }
# #T_b263c_row4_col5 {
#   background-color: #4c9121;
#   color: #f1f1f1;
# }
# #T_b263c_row4_col6 {
#   background-color: #2d6b1a;
#   color: #f1f1f1;
# }
# #T_b263c_row4_col7 {
#   background-color: #c2197a;
#   color: #f1f1f1;
# }
# #T_b263c_row4_col8 {
#   background-color: #d65a9f;
#   color: #f1f1f1;
# }
# #T_b263c_row5_col0 {
#   background-color: #f1f6ea;
#   color: #000000;
# }
# #T_b263c_row5_col2 {
#   background-color: #aa0e68;
#   color: #f1f1f1;
# }
# #T_b263c_row5_col3 {
#   background-color: #509423;
#   color: #f1f1f1;
# }
# #T_b263c_row5_col4 {
#   background-color: #4b8f21;
#   color: #f1f1f1;
# }
# #T_b263c_row5_col6, #T_b263c_row6_col5 {
#   background-color: #43861f;
#   color: #f1f1f1;
# }
# #T_b263c_row5_col7 {
#   background-color: #c62080;
#   color: #f1f1f1;
# }
# #T_b263c_row5_col8 {
#   background-color: #c51d7e;
#   color: #f1f1f1;
# }
# #T_b263c_row6_col0 {
#   background-color: #f5f7f3;
#   color: #000000;
# }
# #T_b263c_row6_col2 {
#   background-color: #a60c65;
#   color: #f1f1f1;
# }
# #T_b263c_row6_col3 {
#   background-color: #3d7f1e;
#   color: #f1f1f1;
# }
# #T_b263c_row6_col4 {
#   background-color: #2b691a;
#   color: #f1f1f1;
# }
# #T_b263c_row6_col7 {
#   background-color: #c82884;
#   color: #f1f1f1;
# }
# #T_b263c_row7_col0 {
#   background-color: #f9f1f5;
#   color: #000000;
# }
# #T_b263c_row7_col1 {
#   background-color: #fbe9f2;
#   color: #000000;
# }
# #T_b263c_row7_col2 {
#   background-color: #d861a2;
#   color: #f1f1f1;
# }
# #T_b263c_row7_col3 {
#   background-color: #fce3f0;
#   color: #000000;
# }
# #T_b263c_row7_col4 {
#   background-color: #e48bbc;
#   color: #f1f1f1;
# }
# #T_b263c_row7_col5 {
#   background-color: #e388ba;
#   color: #f1f1f1;
# }
# #T_b263c_row7_col8 {
#   background-color: #a7d672;
#   color: #000000;
# }
# #T_b263c_row8_col1 {
#   background-color: #fde1ef;
#   color: #000000;
# }
# #T_b263c_row8_col2 {
#   background-color: #f6c7e3;
#   color: #000000;
# }
# #T_b263c_row8_col3 {
#   background-color: #f9d1e8;
#   color: #000000;
# }
# #T_b263c_row8_col4 {
#   background-color: #eda8d1;
#   color: #000000;
# }
# #T_b263c_row8_col5 {
#   background-color: #df79b0;
#   color: #f1f1f1;
# }
# #T_b263c_row8_col7 {
#   background-color: #acd977;
#   color: #000000;
# }
# </style>
# <table id="T_b263c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b263c_level0_col0" class="col_heading level0 col0" >longitude</th>
#       <th id="T_b263c_level0_col1" class="col_heading level0 col1" >latitude</th>
#       <th id="T_b263c_level0_col2" class="col_heading level0 col2" >housing_median_age</th>
#       <th id="T_b263c_level0_col3" class="col_heading level0 col3" >total_rooms</th>
#       <th id="T_b263c_level0_col4" class="col_heading level0 col4" >total_bedrooms</th>
#       <th id="T_b263c_level0_col5" class="col_heading level0 col5" >population</th>
#       <th id="T_b263c_level0_col6" class="col_heading level0 col6" >households</th>
#       <th id="T_b263c_level0_col7" class="col_heading level0 col7" >median_income</th>
#       <th id="T_b263c_level0_col8" class="col_heading level0 col8" >median_house_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b263c_level0_row0" class="row_heading level0 row0" >longitude</th>
#       <td id="T_b263c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b263c_row0_col1" class="data row0 col1" >-0.924341</td>
#       <td id="T_b263c_row0_col2" class="data row0 col2" >-0.110786</td>
#       <td id="T_b263c_row0_col3" class="data row0 col3" >0.043100</td>
#       <td id="T_b263c_row0_col4" class="data row0 col4" >0.069439</td>
#       <td id="T_b263c_row0_col5" class="data row0 col5" >0.100706</td>
#       <td id="T_b263c_row0_col6" class="data row0 col6" >0.056318</td>
#       <td id="T_b263c_row0_col7" class="data row0 col7" >-0.014592</td>
#       <td id="T_b263c_row0_col8" class="data row0 col8" >-0.043603</td>
#     </tr>
#     <tr>
#       <th id="T_b263c_level0_row1" class="row_heading level0 row1" >latitude</th>
#       <td id="T_b263c_row1_col0" class="data row1 col0" >-0.924341</td>
#       <td id="T_b263c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b263c_row1_col2" class="data row1 col2" >0.012640</td>
#       <td id="T_b263c_row1_col3" class="data row1 col3" >-0.036327</td>
#       <td id="T_b263c_row1_col4" class="data row1 col4" >-0.069283</td>
#       <td id="T_b263c_row1_col5" class="data row1 col5" >-0.110514</td>
#       <td id="T_b263c_row1_col6" class="data row1 col6" >-0.073915</td>
#       <td id="T_b263c_row1_col7" class="data row1 col7" >-0.079259</td>
#       <td id="T_b263c_row1_col8" class="data row1 col8" >-0.146324</td>
#     </tr>
#     <tr>
#       <th id="T_b263c_level0_row2" class="row_heading level0 row2" >housing_median_age</th>
#       <td id="T_b263c_row2_col0" class="data row2 col0" >-0.110786</td>
#       <td id="T_b263c_row2_col1" class="data row2 col1" >0.012640</td>
#       <td id="T_b263c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_b263c_row2_col3" class="data row2 col3" >-0.362433</td>
#       <td id="T_b263c_row2_col4" class="data row2 col4" >-0.318544</td>
#       <td id="T_b263c_row2_col5" class="data row2 col5" >-0.291842</td>
#       <td id="T_b263c_row2_col6" class="data row2 col6" >-0.301198</td>
#       <td id="T_b263c_row2_col7" class="data row2 col7" >-0.118410</td>
#       <td id="T_b263c_row2_col8" class="data row2 col8" >0.104714</td>
#     </tr>
#     <tr>
#       <th id="T_b263c_level0_row3" class="row_heading level0 row3" >total_rooms</th>
#       <td id="T_b263c_row3_col0" class="data row3 col0" >0.043100</td>
#       <td id="T_b263c_row3_col1" class="data row3 col1" >-0.036327</td>
#       <td id="T_b263c_row3_col2" class="data row3 col2" >-0.362433</td>
#       <td id="T_b263c_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_b263c_row3_col4" class="data row3 col4" >0.928199</td>

# %%
plt.imshow(correlation_housing.corr(), cmap='jet', interpolation='None')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
housing.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
correlation_housing = housing[['housing_median_age',
                               'total_rooms',
                               'median_income',
                               'median_house_value']]
correlation_housing
# Out:
#        housing_median_age  total_rooms  median_income  median_house_value
# 14196                34.0       6001.0         4.5878            291000.0
# 8267                 10.0        901.0         4.6648            156100.0
# 17445                28.0       6909.0         3.6875            353900.0
# 14265                25.0       4021.0         5.1663            241200.0
# 2271                  8.0        240.0         1.4688             53800.0
# ...                   ...          ...            ...                 ...
# 11284                49.0        969.0         1.3167             71600.0
# 11964                35.0       1778.0         6.5745            379300.0
# 5390                 16.0       2624.0         2.1250            104200.0
# 860                  22.0       2467.0         2.6536             84700.0
# 15795                22.0       1230.0         6.2708            251400.0
#
# [16512 rows x 4 columns]

# %%
pd.plotting.scatter_matrix(correlation_housing, figsize=(10, 10));
plt.show()

# %%
housing['bedrooms_per_room'] = housing['total_bedrooms']/housing['total_rooms']

housing['rooms_per_population'] = housing['total_rooms']/housing['population']

housing['rooms_per_households'] =housing['total_rooms']/housing['households']

# %%
correlation_housing = housing.drop(columns="ocean_proximity")
correlation_housing.corr().style.background_gradient(cmap='PiYG')
# Out:
# <style type="text/css">
# #T_8deb2_row0_col0, #T_8deb2_row1_col1, #T_8deb2_row2_col2, #T_8deb2_row3_col3, #T_8deb2_row4_col4, #T_8deb2_row5_col5, #T_8deb2_row6_col6, #T_8deb2_row7_col7, #T_8deb2_row8_col8, #T_8deb2_row9_col9, #T_8deb2_row10_col10, #T_8deb2_row11_col11 {
#   background-color: #276419;
#   color: #f1f1f1;
# }
# #T_8deb2_row0_col1, #T_8deb2_row1_col0, #T_8deb2_row2_col3, #T_8deb2_row2_col4, #T_8deb2_row2_col5, #T_8deb2_row2_col6, #T_8deb2_row3_col2, #T_8deb2_row7_col9, #T_8deb2_row9_col7, #T_8deb2_row9_col8, #T_8deb2_row9_col10, #T_8deb2_row9_col11 {
#   background-color: #8e0152;
#   color: #f1f1f1;
# }
# #T_8deb2_row0_col2 {
#   background-color: #da69a6;
#   color: #f1f1f1;
# }
# #T_8deb2_row0_col3 {
#   background-color: #f1b5d9;
#   color: #000000;
# }
# #T_8deb2_row0_col4 {
#   background-color: #f0b2d7;
#   color: #000000;
# }
# #T_8deb2_row0_col5 {
#   background-color: #f1b7da;
#   color: #000000;
# }
# #T_8deb2_row0_col6, #T_8deb2_row1_col2 {
#   background-color: #eca6cf;
#   color: #000000;
# }
# #T_8deb2_row0_col7, #T_8deb2_row4_col7 {
#   background-color: #fad4e9;
#   color: #000000;
# }
# #T_8deb2_row0_col8 {
#   background-color: #d65a9f;
#   color: #f1f1f1;
# }
# #T_8deb2_row0_col9, #T_8deb2_row4_col9, #T_8deb2_row7_col1 {
#   background-color: #fbe9f2;
#   color: #000000;
# }
# #T_8deb2_row0_col10 {
#   background-color: #cf4191;
#   color: #f1f1f1;
# }
# #T_8deb2_row0_col11 {
#   background-color: #ea9fca;
#   color: #000000;
# }
# #T_8deb2_row1_col3, #T_8deb2_row7_col6 {
#   background-color: #e590bf;
#   color: #f1f1f1;
# }
# #T_8deb2_row1_col4, #T_8deb2_row10_col2 {
#   background-color: #db6ca8;
#   color: #f1f1f1;
# }
# #T_8deb2_row1_col5 {
#   background-color: #ce3d8f;
#   color: #f1f1f1;
# }
# #T_8deb2_row1_col6 {
#   background-color: #d75ea1;
#   color: #f1f1f1;
# }
# #T_8deb2_row1_col7 {
#   background-color: #f5c4e1;
#   color: #000000;
# }
# #T_8deb2_row1_col8 {
#   background-color: #bd1777;
#   color: #f1f1f1;
# }
# #T_8deb2_row1_col9, #T_8deb2_row3_col8 {
#   background-color: #f2badc;
#   color: #000000;
# }
# #T_8deb2_row1_col10 {
#   background-color: #f4c1df;
#   color: #000000;
# }
# #T_8deb2_row1_col11, #T_8deb2_row8_col10 {
#   background-color: #f9d3e8;
#   color: #000000;
# }
# #T_8deb2_row2_col0, #T_8deb2_row5_col1, #T_8deb2_row9_col1 {
#   background-color: #fce5f1;
#   color: #000000;
# }
# #T_8deb2_row2_col1 {
#   background-color: #f8f4f6;
#   color: #000000;
# }
# #T_8deb2_row2_col7, #T_8deb2_row3_col10 {
#   background-color: #f2b8db;
#   color: #000000;
# }
# #T_8deb2_row2_col8 {
#   background-color: #eeadd4;
#   color: #000000;
# }
# #T_8deb2_row2_col9 {
#   background-color: #f9eff4;
#   color: #000000;
# }
# #T_8deb2_row2_col10 {
#   background-color: #cb3289;
#   color: #f1f1f1;
# }
# #T_8deb2_row2_col11, #T_8deb2_row5_col8, #T_8deb2_row6_col10 {
#   background-color: #d965a4;
#   color: #f1f1f1;
# }
# #T_8deb2_row3_col0, #T_8deb2_row3_col7 {
#   background-color: #f7f7f6;
#   color: #000000;
# }
# #T_8deb2_row3_col1, #T_8deb2_row8_col0, #T_8deb2_row11_col0 {
#   background-color: #f9eef4;
#   color: #000000;
# }
# #T_8deb2_row3_col4, #T_8deb2_row4_col3 {
#   background-color: #3a7b1d;
#   color: #f1f1f1;
# }
# #T_8deb2_row3_col5 {
#   background-color: #549825;
#   color: #f1f1f1;
# }
# #T_8deb2_row3_col6 {
#   background-color: #3f811e;
#   color: #f1f1f1;
# }
# #T_8deb2_row3_col9 {
#   background-color: #eba1cb;
#   color: #000000;
# }
# #T_8deb2_row3_col11 {
#   background-color: #fad6ea;
#   color: #000000;
# }
# #T_8deb2_row4_col0 {
#   background-color: #f4f7f0;
#   color: #000000;
# }
# #T_8deb2_row4_col1, #T_8deb2_row6_col1 {
#   background-color: #faeaf2;
#   color: #000000;
# }
# #T_8deb2_row4_col2 {
#   background-color: #9f095f;
#   color: #f1f1f1;
# }
# #T_8deb2_row4_col5 {
#   background-color: #4c9121;
#   color: #f1f1f1;
# }
# #T_8deb2_row4_col6 {
#   background-color: #2d6b1a;
#   color: #f1f1f1;
# }
# #T_8deb2_row4_col8 {
#   background-color: #e692c1;
#   color: #000000;
# }
# #T_8deb2_row4_col10 {
#   background-color: #e795c3;
#   color: #000000;
# }
# #T_8deb2_row4_col11, #T_8deb2_row8_col6 {
#   background-color: #eeabd2;
#   color: #000000;
# }
# #T_8deb2_row5_col0 {
#   background-color: #f1f6ea;
#   color: #000000;
# }
# #T_8deb2_row5_col2 {
#   background-color: #aa0e68;
#   color: #f1f1f1;
# }
# #T_8deb2_row5_col3 {
#   background-color: #509423;
#   color: #f1f1f1;
# }
# #T_8deb2_row5_col4 {
#   background-color: #4b8f21;
#   color: #f1f1f1;
# }
# #T_8deb2_row5_col6, #T_8deb2_row6_col5, #T_8deb2_row10_col11 {
#   background-color: #43861f;
#   color: #f1f1f1;
# }
# #T_8deb2_row5_col7 {
#   background-color: #fbd8eb;
#   color: #000000;
# }
# #T_8deb2_row5_col9 {
#   background-color: #fde2f0;
#   color: #000000;
# }
# #T_8deb2_row5_col10 {
#   background-color: #c2197a;
#   color: #f1f1f1;
# }
# #T_8deb2_row5_col11, #T_8deb2_row11_col4 {
#   background-color: #e58dbe;
#   color: #f1f1f1;
# }
# #T_8deb2_row6_col0, #T_8deb2_row7_col11 {
#   background-color: #f5f7f3;
#   color: #000000;
# }
# #T_8deb2_row6_col2 {
#   background-color: #a60c65;
#   color: #f1f1f1;
# }
# #T_8deb2_row6_col3 {
#   background-color: #3d7f1e;
#   color: #f1f1f1;
# }
# #T_8deb2_row6_col4 {
#   background-color: #2b691a;
#   color: #f1f1f1;
# }
# #T_8deb2_row6_col7, #T_8deb2_row7_col10 {
#   background-color: #fcdbed;
#   color: #000000;
# }
# #T_8deb2_row6_col8 {
#   background-color: #e89ac6;
#   color: #000000;
# }
# #T_8deb2_row6_col9 {
#   background-color: #fbe6f1;
#   color: #000000;
# }
# #T_8deb2_row6_col11, #T_8deb2_row7_col5 {
#   background-color: #e388ba;
#   color: #f1f1f1;
# }
# #T_8deb2_row7_col0 {
#   background-color: #f9f1f5;
#   color: #000000;
# }
# #T_8deb2_row7_col2 {
#   background-color: #d861a2;
#   color: #f1f1f1;
# }
# #T_8deb2_row7_col3 {
#   background-color: #fce3f0;
#   color: #000000;
# }
# #T_8deb2_row7_col4 {
#   background-color: #e48bbc;
#   color: #f1f1f1;
# }
# #T_8deb2_row7_col8 {
#   background-color: #9acd61;
#   color: #000000;
# }
# #T_8deb2_row8_col1 {
#   background-color: #fde1ef;
#   color: #000000;
# }
# #T_8deb2_row8_col2 {
#   background-color: #f6c7e3;
#   color: #000000;
# }
# #T_8deb2_row8_col3, #T_8deb2_row9_col2, #T_8deb2_row10_col8 {
#   background-color: #f9d1e8;
#   color: #000000;
# }
# #T_8deb2_row8_col4, #T_8deb2_row10_col4 {
#   background-color: #eda8d1;
#   color: #000000;
# }
# #T_8deb2_row8_col5, #T_8deb2_row10_col6 {
#   background-color: #df79b0;
#   color: #f1f1f1;
# }
# #T_8deb2_row8_col7 {
#   background-color: #7bb93e;
#   color: #f1f1f1;
# }
# #T_8deb2_row8_col9 {
#   background-color: #e286b8;
#   color: #f1f1f1;
# }
# #T_8deb2_row8_col11 {
#   background-color: #fcdded;
#   color: #000000;
# }
# #T_8deb2_row9_col0 {
#   background-color: #f2f6ec;
#   color: #000000;
# }
# #T_8deb2_row9_col3, #T_8deb2_row11_col9 {
#   background-color: #cc368b;
#   color: #f1f1f1;
# }
# #T_8deb2_row9_col4 {
#   background-color: #f3bcdd;
#   color: #000000;
# }
# #T_8deb2_row9_col5 {
#   background-color: #e99cc8;
#   color: #000000;
# }
# #T_8deb2_row9_col6 {
#   background-color: #efb0d6;
#   color: #000000;
# }
# #T_8deb2_row10_col0 {
#   background-color: #fbe8f2;
#   color: #000000;
# }
# #T_8deb2_row10_col1 {
#   background-color: #edf6e1;
#   color: #000000;
# }
# #T_8deb2_row10_col3, #T_8deb2_row11_col3 {
#   background-color: #f8cee6;
#   color: #000000;
# }
# #T_8deb2_row10_col5 {
#   background-color: #c82884;
#   color: #f1f1f1;
# }
# #T_8deb2_row10_col7 {
#   background-color: #f3f7ef;
#   color: #000000;
# }
# #T_8deb2_row10_col9 {
#   background-color: #e181b5;
#   color: #f1f1f1;
# }
# #T_8deb2_row11_col1 {
#   background-color: #f1f6e8;
#   color: #000000;
# }
# #T_8deb2_row11_col2 {
#   background-color: #d34f99;
#   color: #f1f1f1;
# }
# #T_8deb2_row11_col5, #T_8deb2_row11_col6 {
#   background-color: #d5579d;
#   color: #f1f1f1;
# }
# #T_8deb2_row11_col7 {
#   background-color: #eaf5d9;
#   color: #000000;
# }
# #T_8deb2_row11_col8 {
#   background-color: #f3bdde;
#   color: #000000;
# }
# #T_8deb2_row11_col10 {
#   background-color: #488c20;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8deb2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8deb2_level0_col0" class="col_heading level0 col0" >longitude</th>
#       <th id="T_8deb2_level0_col1" class="col_heading level0 col1" >latitude</th>
#       <th id="T_8deb2_level0_col2" class="col_heading level0 col2" >housing_median_age</th>
#       <th id="T_8deb2_level0_col3" class="col_heading level0 col3" >total_rooms</th>
#       <th id="T_8deb2_level0_col4" class="col_heading level0 col4" >total_bedrooms</th>
#       <th id="T_8deb2_lev
